# %% [markdown]
# # ML-07 — Baseline Action Score and Top-20 Review
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/hkamran808/ml-internship-flyrank/blob/main/work/notebooks/w04_baseline_score.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
with open('building-baselines/SKILL.md', 'r') as f:
    skill_content = f.read()
print(skill_content)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1628/980724608.py in <cell line: 0>()
# ----> 1 with open('building-baselines/SKILL.md', 'r') as f:
#       2     skill_content = f.read()
#       3 print(skill_content)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'building-baselines/SKILL.md'

# %%
# !pwd
# Out:
# /content

# %%
# !find / -name "SKILL.md"
# Out:
# find: ‘/proc/65/task/65/net’: Invalid argument
# find: ‘/proc/65/net’: Invalid argument
# /usr/local/lib/python3.13/dist-packages/google/adk/tools/bigquery/skills/bigquery-ai-ml/SKILL.md
# /usr/local/lib/python3.13/dist-packages/google/adk/tools/bigquery/skills/bigquery-graph/SKILL.md
# /usr/local/lib/python3.13/dist-packages/typer/.agents/skills/typer/SKILL.md
# /usr/local/lib/python3.13/dist-packages/fastapi/.agents/skills/fastapi/SKILL.md
# /tools/node/lib/node_modules/@google/gemini-cli/bundle/builtin/skill-creator/SKILL.md
# /tools/node/lib/node_modules/@google/gemini-cli/bundle/builtin/antigravity-support/SKILL.md
# /tools/node/lib/node_modules/@google/gemini-cli/bundle/examples/skills/skills/greeter/SKILL.md

# %%
# !find / -name "skills"
# Out:
# find: ‘/proc/65/task/65/net’: Invalid argument
# find: ‘/proc/65/net’: Invalid argument
# /usr/local/lib/python3.13/dist-packages/google/adk/tools/bigquery/skills
# /usr/local/lib/python3.13/dist-packages/google/adk/skills
# /usr/local/lib/python3.13/dist-packages/typer/.agents/skills
# /usr/local/lib/python3.13/dist-packages/fastapi/.agents/skills
# /usr/local/lib/python3.13/dist-packages/openai/resources/skills
# /usr/local/lib/python3.13/dist-packages/openai/types/skills
# /tools/node/lib/node_modules/@google/gemini-cli/bundle/examples/skills
# /tools/node/lib/node_modules/@google/gemini-cli/bundle/examples/skills/skills
# /tools/google-cloud-sdk/lib/surface/agent_registry/skills

# %%
# !find / -type f -name "README.md" -path "*/skills/*"
# Out:
# find: ‘/proc/65/task/65/net’: Invalid argument
# find: ‘/proc/65/net’: Invalid argument

# %%
# !ls -R
# Out:
# .:
# sample_data
#
# ./sample_data:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %% [markdown]
# ## 1. My rule and its reason codes
#
# *Write the rule in plain words first. Then the reason codes it can output.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Build the ranked queue (writes the CSV)
#
# *Code the score, rank everything, write work/outputs/baseline_action_score.csv.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Top-20 review
#
# *For each of the top 20: action, reason code, confidence note, and what would make it wrong.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Weak picks + leakage check
#
# *Which picks look wrong and why? Confirm no product flags or future windows leaked in.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
